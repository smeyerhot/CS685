# %%
from collections import defaultdict
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn import metrics
import myfm
import pandas as pd
import json
import torch
from sklearn.model_selection import train_test_split

# %%
data = pd.read_pickle('usersAndSubs.pkl')
s2c = pd.read_pickle('subs2comments.pkl')
tdf = pd.read_pickle('tdf.pkl')

# %%
with open('s2Id.json', 'r') as fp:
    s2I = json.load(fp)

# %%
data.head()
# Out:
#    user_id  reddit_id  rating
# 0        1          1       1
# 1        1         66       1
# 2        1        134       1
# 3        1          2       1
# 4        1         10       1

# %%
s2c.head()
# Out:
#    reddit_id                                            comment
# 0          1  [I think it should be fixed on either UTC stan...
# 1          2  [Art is about the hardest thing to categorize ...
# 2          3  [Ask me what I think about the Wall Street Jou...
# 3          4  [In Mechwarrior Online, I have begun to use a ...
# 4          5  [You are talking about the Charsi imbue, right...

# %%
tdf.head()
# Out:
#    index        subreddit  rating  reddit_id
# 0      0             math     101          1
# 1      1         Frontend     101       3898
# 2      2         ethereum     101       3276
# 3      3  MachineLearning     104       2944
# 4      4       artificial     101       2279

# %%
s2I
# Out:
# {'math': 1,
#  'funny': 2,
#  'Borderlands': 3,
#  'gamingpc': 4,
#  'Diablo': 5,
#  'RedditLaqueristas': 6,
#  'apple': 7,
#  'RedditFilmsProduction': 8,
#  'AbandonedPorn': 9,
#  'atheism': 10,
#  'quotes': 11,
#  'AskReddit': 12,
#  'personalfinance': 13,
#  'Animals': 14,
#  'leagueoflegends': 15,
#  'videos': 16,
#  'trees': 17,
#  'Games': 18,
#  'rawdenim': 19,
#  'BMW': 20,
#  'Guitar': 21,
#  'tf2': 22,
#  'truegaming': 23,
#  'swtor': 24,
#  'anime': 25,
#  'relationship_advice': 26,
#  'TwoXChromosomes': 27,
#  'AdviceAnimals': 28,
#  'Minecraft': 29,
#  'motorcycles': 30,
#  'firefall': 31,
#  'audiophile': 32,
#  'SRSDiscussion': 33,
#  'explainlikeimfive': 34,
#  'WTF': 35,
#  'linux': 36,
#  'LambdaConspiracies': 37,
#  'YouShouldKnow': 38,
#  'fffffffuuuuuuuuuuuu': 39,
#  'cars': 40,
#  'TrueAskReddit': 41,
#  'boardgames': 42,
#  'childfree': 43,
#  'business': 44,
#  'starcraft': 45,
#  'antisrs': 46,
#  'todayilearned': 47,
#  'festivals': 48,
#  'askseddit': 49,
#  'Guildwars2': 50,
#  'melbourne': 51,
#  'Military': 52,
#  'technology': 53,
#  'science': 54,
#  'running': 55,
#  'worldnews': 56,
#  'Bass': 57,
#  'MECoOp': 58,
#  'bjj': 59,
#  'uwaterloo': 60,
#  'DotA2': 61,
#  'ecology': 62,
#  'answers': 63,
#  'zelda': 64,
#  'unitedkingdom': 65,
#  'pics': 66,
#  'talesfromtechsupport': 67,
#  'relationships': 68,
#  'allthingszerg': 69,
#  'MensRights': 70,
#  'JoeRogan': 71,
#  'gamedev': 72,
#  'NAU': 73,
#  'politics': 74,
#  'Torchlight': 75,
#  'navy': 76,
#  'AskCulinary': 77,
#  'Paleo': 78,
#  'gaming': 79,
#  'WeAreTheMusicMakers': 80,
#  'zombies': 81,
#  'berlin': 82,
#  'sex': 83,
#  'gallifrey': 84,
#  'hardstyle': 85,
#  'Eve': 86,
#  'wow': 87,
#  'Music': 88,
#  'OkCupid': 89,
#  'stocks': 90,
#  'IAmA': 91,
#  'nfl': 92,
#  'diablo3': 93,
#  'hardware': 94,
#  'GirlGamers': 95,
#  'buildapc': 96,
#  'MTSU': 97,
#  'CFB': 98,
#  'KerbalSpaceProgram': 99,
#  'xbox360': 100,
#  'minimalism': 101,
#  'magicTCG': 102,
#  'crossdressing': 103,
#  'Drugs': 104,
#  'gardening': 105,
#  'chicago': 106,
#  'Civcraft': 107,
#  'EA_NHL': 108,
#  'hockey': 109,
#  'rpg': 110,
#  'Pathfinder_RPG': 111,
#  'pokemon': 112,
#  'travel': 113,
#  'gentlemanboners': 114,
#  'worldevents': 115,
#  'CHIBears': 116,
#  'LadyMRAs': 117,
#  'TrueReddit': 118,
#  'halo': 119,
#  'islam': 120,
#  'truezelda': 121,
#  'orlando': 122,
#  'community': 123,
#  'australia': 124,
#  'dating_advice': 125,
#  'arduino': 126,
#  'skyrim': 127,
#  'PHP': 128,
#  'lostgeneration': 129,
#  'vegan': 130,
#  'NoFap': 131,
#  'conspiratard': 132,
#  'shutupandtakemymoney': 133,
#  'Christianity': 134,
#  'AskScienceFiction': 135,
#  'Android': 136,
#  'Anxiety': 137,
#  'memes': 138,
#  'Conservative': 139,
#  'circlejerk': 140,
#  'MMA': 141,
#  'canada': 142,
#  'pettyrevenge': 143,
#  'feedthebeast': 144,
#  'starcitizen': 145,
#  'bourbon': 146,
#  'food': 147,
#  'snowboarding': 148,
#  'dogs': 149,
#  'Frugal': 150,
#  'DebateAnAtheist': 151,
#  'learnprogramming': 152,
#  'space': 153,
#  'TrueAtheism': 154,
#  'Rift': 155,
#  'santashelpers': 156,
#  'mwo': 157,
#  'TalesFromRetail': 158,
#  'mildlyinteresting': 159,
#  'TheWarZ': 160,
#  'berkeley': 161,
#  'RandomActsOfPolish': 162,
#  'loseit': 163,
#  'batman_comics': 164,
#  'longboarding': 165,
#  'entertainment': 166,
#  'BDSMcommunity': 167,
#  'Sidehugs': 168,
#  'Meditation': 169,
#  '4chan': 170,
#  'SuicideWatch': 171,
#  'Shadowrun': 172,
#  'AskWomen': 173,
#  'malefashionadvice': 174,
#  'Austin': 175,
#  'AskMen': 176,
#  'Nexus7': 177,
#  'summonerschool': 178,
#  'detroitlions': 179,
#  'CherokeeXJ': 180,
#  'cocktails': 181,
#  'nba': 182,
#  'nyc': 183,
#  'Frat': 184,
#  'circlebroke': 185,
#  'overclocking': 186,
#  'hookah': 187,
#  'thrashmetal': 188,
#  'LucidDreaming': 189,
#  'SEO': 190,
#  'energy': 191,
#  'korea': 192,
#  'europe': 193,
#  'Anarchism': 194,
#  'photography': 195,
#  'Metallica': 196,
#  'JamesBond': 197,
#  'rpg_gamers': 198,
#  'cringe': 199,
#  'law': 200,
#  'socialskills': 201,
#  'harrypotter': 202,
#  'RESissues': 203,
#  'tifu': 204,
#  'HeroesofNewerth': 205,
#  'acne': 206,
#  'google': 207,
#  'ftlgame': 208,
#  'Gunners': 209,
#  '7String': 210,
#  'Warhammer': 211,
#  'jobs': 212,
#  'aww': 213,
#  'darksouls': 214,
#  'olderlesbians': 215,
#  'battlefield3': 216,
#  'ProtectAndServe': 217,
#  'resumes': 218,
#  'askscience': 219,
#  'fantasyfootball': 220,
#  'confession': 221,
#  'startrek': 222,
#  'Patriots': 223,
#  'agnostic': 224,
#  'DoesAnybodyElse': 225,
#  'Documentaries': 226,
#  'Fitness': 227,
#  'eldertrees': 228,
#  'wicked_edge': 229,
#  'LawSchool': 230,
#  'JusticePorn': 231,
#  'Physics': 232,
#  'iphone': 233,
#  'SF4': 234,
#  'IWantToLearn': 235,
#  'cincinnati': 236,
#  'paradoxplaza': 237,
#  'Connecticut': 238,
#  'PointsPlus': 239,
#  'KarmaCourt': 240,
#  'askaconservative': 241,
#  'keto': 242,
#  'OnePiece': 243,
#  'BabyBumps': 244,
#  'AskHistorians': 245,
#  'HIMYM': 246,
#  'OrlandoMagic': 247,
#  'electricdaisycarnival': 248,
#  'AirForce': 249,
#  'guns': 250,
#  'GameDeals': 251,
#  'skeptic': 252,
#  'electronic_cigarette': 253,
#  'teenagers': 254,
#  'conspiracy': 255,
#  'belgium': 256,
#  'NFL_Draft': 257,
#  'AllThingsTerran': 258,
#  'Teachers': 259,
#  'vegas': 260,
#  'TumblrInAction': 261,
#  'leangains': 262,
#  'DebateReligion': 263,
#  'Random_Acts_Of_Pizza': 264,
#  'StarWars': 265,
#  'doctorwho': 266,
#  'autism': 267,
#  'webdev': 268,
#  'WebGames': 269,
#  'Hunting': 270,
#  'networking': 271,
#  'puppy101': 272,
#  'fantasybball': 273,
#  'SubredditDrama': 274,
#  'DevilMayCry': 275,
#  'Boxing': 276,
#  'nursing': 277,
#  'Warhammer40k': 278,
#  'GunsAreCool': 279,
#  'philosophy': 280,
#  'okc': 281,
#  'moderatepolitics': 282,
#  'woahdude': 283,
#  'AutoDetailing': 284,
#  'movies': 285,
#  'exmormon': 286,
#  'drums': 287,
#  '3DS': 288,
#  'Ingress': 289,
#  'ClashOfClans': 290,
#  'Smite': 291,
#  'sysadmin': 292,
#  'xxfitness': 293,
#  'DepthHub': 294,
#  'MLPLounge': 295,
#  'voluntarism': 296,
#  'C25K': 297,
#  'ar15': 298,
#  'Metal': 299,
#  'psbattleroyale': 300,
#  'Demotivational': 301,
#  'worldpolitics': 302,
#  'investing': 303,
#  'tattoos': 304,
#  'PoliticalDiscussion': 305,
#  'Tribes': 306,
#  'sandiego': 307,
#  'pathofexile': 308,
#  'crossfit': 309,
#  'runescape': 310,
#  'SpecialAccess': 311,
#  'LV426': 312,
#  'ADHD': 313,
#  'Fibromyalgia': 314,
#  'nonmonogamy': 315,
#  'airsoft': 316,
#  'AskSocialScience': 317,
#  'mylittlepony': 318,
#  'OpiatesRecovery': 319,
#  'Animewallpaper': 320,
#  'Gameboy': 321,
#  'preppers': 322,
#  'beer': 323,
#  'whowouldwin': 324,
#  'philadelphia': 325,
#  'Libertarian': 326,
#  'applehelp': 327,
#  'gaybros': 328,
#  'getdisciplined': 329,
#  'formula1': 330,
#  'flatcore': 331,
#  'RATS': 332,
#  'LifeProTips': 333,
#  'news': 334,
#  'prowrestling': 335,
#  'PS4': 336,
#  'bigboobproblems': 337,
#  'howtonotgiveafuck': 338,
#  'engineering': 339,
#  'PhilosophyofScience': 340,
#  'Naruto': 341,
#  'classicrage': 342,
#  'seduction': 343,
#  'printSF': 344,
#  'Quidditch': 345,
#  'Anticonsumption': 346,
#  'FL_Studio': 347,
#  'asoiaf': 348,
#  'piercing': 349,
#  'changemyview': 350,
#  'cigars': 351,
#  'ptsd': 352,
#  'gifs': 353,
#  'Wicca': 354,
#  'ArcherFX': 355,
#  'Parenting': 356,
#  'amazon': 357,
#  'BreakUps': 358,
#  'SWORDS': 359,
#  'girlsinyogapants': 360,
#  'computers': 361,
#  'Rolla': 362,
#  'SimCity': 363,
#  'nuzlocke': 364,
#  'gameofthrones': 365,
#  'gonewild': 366,
#  'reptiles': 367,
#  'Suomi': 368,
#  'Seattle': 369,
#  'doublelift': 370,
#  'gunpolitics': 371,
#  'safc': 372,
#  'WhatsInThisThing': 373,
#  'TheMentalist': 374,
#  'Ask_Politics': 375,
#  'EA_FIFA': 376,
#  'WorldofTanks': 377,
#  'sanfrancisco': 378,
#  'TrueFilm': 379,
#  'assassinscreed': 380,
#  'biology': 381,
#  'christianyouth': 382,
#  'pokemonconspiracies': 383,
#  'Economics': 384,
#  'Israel': 385,
#  'DaystromInstitute': 386,
#  'offmychest': 387,
#  'tf2trade': 388,
#  'DCcomics': 389,
#  'lifehacks': 390,
#  'Supplements': 391,
#  'mormon': 392,
#  'CollegeBasketball': 393,
#  'cringepics': 394,
#  'malaysia': 395,
#  'BeardedDragons': 396,
#  'INTP': 397,
#  'southcarolina': 398,
#  'realasians': 399,
#  'saplings': 400,
#  'opiates': 401,
#  'ShouldIbuythisgame': 402,
#  'linguistics': 403,
#  'tolkienfans': 404,
#  'psychopharmacology': 405,
#  'MakeupAddiction': 406,
#  'Bitcoin': 407,
#  'TalesFromYourServer': 408,
#  'techsupport': 409,
#  'Metroid': 410,
#  'Planetside': 411,
#  'fcbayern': 412,
#  'Cyberpunk': 413,
#  'windows': 414,
#  'DnD': 415,
#  'wendywright': 416,
#  'baseball': 417,
#  'EngineeringStudents': 418,
#  'SS13': 419,
#  'ChronicPain': 420,
#  'readablecode': 421,
#  'superman': 422,
#  'bugout': 423,
#  'Random_Acts_Of_Amazon': 424,
#  'editors': 425,
#  'oculus': 426,
#  'arresteddevelopment': 427,
#  'facepalm': 428,
#  'HannibalTV': 429,
#  'WestboroBaptistChurch': 430,
#  'Warthunder': 431,
#  'actuallesbians': 432,
#  'londonfootballmeetup': 433,
#  'UFOs': 434,
#  'DebateAChristian': 435,
#  'amateurradio': 436,
#  'counterstrike': 437,
#  'Dogtraining': 438,
#  'RandomActsofMakeup': 439,
#  'WGU': 440,
#  'redsox': 441,
#  'CODZombies': 442,
#  'HPMOR': 443,
#  'metalmusicians': 444,
#  'MorbidReality': 445,
#  'DIY': 446,
#  'shittyaskscience': 447,
#  'MLS': 448,
#  'diabetes': 449,
#  'AndroidQuestions': 450,
#  'WarriorCats': 451,
#  'environment': 452,
#  'RBA': 453,
#  'MURICA': 454,
#  'GreatScenes': 455,
#  'secondlife': 456,
#  'nintendo': 457,
#  'Warframe': 458,
#  'microgrowery': 459,
#  'Homebrewing': 460,
#  'treecomics': 461,
#  'television': 462,
#  'virtualreality': 463,
#  'bipolar': 464,
#  'LosAngeles': 465,
#  'ShortScaryStoriesOOC': 466,
#  'DaftPunk': 467,
#  'ForeverAlone': 468,
#  'Neverwinter': 469,
#  'RandomActsOfGaming': 470,
#  'bestof': 471,
#  'dayz': 472,
#  'Diablo3Monks': 473,
#  'exjw': 474,
#  'startups': 475,
#  'RPI': 476,
#  'Entrepreneur': 477,
#  'xmen': 478,
#  'JRPG': 479,
#  'thewalkingdead': 480,
#  'PropagandaPosters': 481,
#  'bodybuilding': 482,
#  'Genealogy': 483,
#  'EnoughLibertarianSpam': 484,
#  'Shitstatistssay': 485,
#  'pcgaming': 486,
#  'depression': 487,
#  'Buddhism': 488,
#  'techsupportgore': 489,
#  'starbucks': 490,
#  'Anarcho_Capitalism': 491,
#  'longrange': 492,
#  'blackladies': 493,
#  'allthingsprotoss': 494,
#  'france': 495,
#  'boobsandbottles': 496,
#  'swedents': 497,
#  'Mustang': 498,
#  'NewToTF2': 499,
#  'eagles': 500,
#  'MineZ': 501,
#  'mallninjashit': 502,
#  'Magicdeckbuilding': 503,
#  'TheLastAirbender': 504,
#  'MyLittleSupportGroup': 505,
#  'badhistory': 506,
#  'itmejp': 507,
#  'homestead': 508,
#  'beards': 509,
#  'stripsearch': 510,
#  'legaladvice': 511,
#  'MonsterHunter': 512,
#  'ENFP': 513,
#  'phoenix': 514,
#  'loremasters': 515,
#  'doublespeakprivilege': 516,
#  'thelastofus': 517,
#  'masseffect': 518,
#  'PlayStationPlus': 519,
#  'photocritique': 520,
#  'TheFacebookDelusion': 521,
#  'gay': 522,
#  'ainbow': 523,
#  'DecidingToBeBetter': 524,
#  'realdubstep': 525,
#  'newhampshire': 526,
#  'Cooking': 527,
#  'wiiu': 528,
#  'CubeWorld': 529,
#  'rage': 530,
#  'moviescirclejerk': 531,
#  'minerapocalypse': 532,
#  'StockMarket': 533,
#  'amiugly': 534,
#  'Wordpress': 535,
#  'computertechs': 536,
#  'totalwar': 537,
#  'writing': 538,
#  'TrayvonMartin': 539,
#  'Judaism': 540,
#  'nononono': 541,
#  'MINI': 542,
#  'sociology': 543,
#  'casualiama': 544,
#  'babywearing': 545,
#  'FifaCareers': 546,
#  'india': 547,
#  'whatisthisthing': 548,
#  'windowsphone': 549,
#  'rugbyunion': 550,
#  'TheRedPill': 551,
#  'RadicalChristianity': 552,
#  'vaporents': 553,
#  'asktransgender': 554,
#  'polyamory': 555,
#  'nhl': 556,
#  'DebateaCommunist': 557,
#  'BigBrother': 558,
#  'cade': 559,
#  'NarFFL': 560,
#  'argentina': 561,
#  'Xcom': 562,
#  'internationalbusiness': 563,
#  'bisexual': 564,
#  'xboxone': 565,
#  'MechanicalKeyboards': 566,
#  'socialism': 567,
#  'ouya': 568,
#  'Bombing': 569,
#  'homestuck': 570,
#  'fatpeoplestories': 571,
#  'geek': 572,
#  'Cockatrice': 573,
#  'wii': 574,
#  'SexWithDogs': 575,
#  'Feminism': 576,
#  'AskAnthropology': 577,
#  'conservatives': 578,
#  'Sneakers': 579,
#  'iosgaming': 580,
#  'razer': 581,
#  'mindcrack': 582,
#  'LearnUselessTalents': 583,
#  'worldbuilding': 584,
#  'ffxiv': 585,
#  'FinalFantasy': 586,
#  'Jazz': 587,
#  'flying': 588,
#  'smashbros': 589,
#  'mlb': 590,
#  'FancyFollicles': 591,
#  'SNSD': 592,
#  'soccer': 593,
#  'see': 594,
#  'Utrecht': 595,
#  'Romania': 596,
#  'PickAnAndroidForMe': 597,
#  'Nerf': 598,
#  'P90X': 599,
#  'DeepSpaceNine': 600,
#  'Gunpla': 601,
#  'gonewildstories': 602,
#  'SFGiants': 603,
#  'talesfromcallcenters': 604,
#  'Pillarchy': 605,
#  'NYCbike': 606,
#  'FloridaPanthers': 607,
#  'admincraft': 608,
#  'SteamGameSwap': 609,
#  'coys': 610,
#  'reactiongifs': 611,
#  'audioengineering': 612,
#  'Pets': 613,
#  'PoliticalHumor': 614,
#  'pitbulls': 615,
#  'cscareerquestions': 616,
#  'vita': 617,
#  'vinyl': 618,
#  'YellowcardRock': 619,
#  'comicbooks': 620,
#  'youtubecomments': 621,
#  'explainlikeIAmA': 622,
#  'syriancivilwar': 623,
#  'EatingDisorders': 624,
#  'montreal': 625,
#  'LiverpoolFC': 626,
#  'misfitstv': 627,
#  'Velo': 628,
#  'Thailand': 629,
#  'singing': 630,
#  'yugioh': 631,
#  'Seahawks': 632,
#  'NoStupidQuestions': 633,
#  'Design': 634,
#  'AskTechnology': 635,
#  'Drifting': 636,
#  'peacecorps': 637,
#  'alpinism': 638,
#  'learnart': 639,
#  'GrandTheftAutoV': 640,
#  'programming': 641,
#  'ems': 642,
#  'self': 643,
#  'ImGoingToHellForThis': 644,
#  'WildStar': 645,
#  'psychology': 646,
#  'GlobalOffensive': 647,
#  'Kayaking': 648,
#  'Denmark': 649,
#  'htcone': 650,
#  'WKU': 651,
#  'PercyJacksonRP': 652,
#  'woweconomy': 653,
#  'GTAV': 654,
#  'pcmasterrace': 655,
#  'HuntsvilleAlabama': 656,
#  'publichealth': 657,
#  'Philippines': 658,
#  'guitarlessons': 659,
#  'uofm': 660,
#  'Trucks': 661,
#  'astrophotography': 662,
#  'powerlifting': 663,
#  'translator': 664,
#  'Paranormal': 665,
#  'breakingbad': 666,
#  'SaltLakeCity': 667,
#  'history': 668,
#  'femalefashionadvice': 669,
#  'CookieClicker': 670,
#  'ProjectRunway': 671,
#  'UofT': 672,
#  'Detroit': 673,
#  'GoNets': 674,
#  'CrusaderKings': 675,
#  'DebateAnarchism': 676,
#  'Atlanta': 677,
#  'ucf': 678,
#  'pornfree': 679,
#  'vegetarian': 680,
#  'homeowners': 681,
#  'sports': 682,
#  'climbing': 683,
#  'RWBY': 684,
#  'manga': 685,
#  'england': 686,
#  'houston': 687,
#  'Chinese': 688,
#  'Louisiana': 689,
#  'Watches': 690,
#  'SoundersFC': 691,
#  'Volkswagen': 692,
#  'frugalmalefashion': 693,
#  'LeagueofLegendsMeta': 694,
#  'asktrp': 695,
#  'batman': 696,
#  'SSBPM': 697,
#  'yoga': 698,
#  'Nirvana': 699,
#  'fitmeals': 700,
#  'highdeas': 701,
#  'minecraftsuggestions': 702,
#  'GetMotivated': 703,
#  'Polska': 704,
#  'Brooklyn': 705,
#  'disney': 706,
#  'mexico': 707,
#  'LongDistance': 708,
#  'Sonsofanarchy': 709,
#  'chile': 710,
#  'Cheap_Meals': 711,
#  'cats': 712,
#  'nosleep': 713,
#  '4x4': 714,
#  'thatHappened': 715,
#  'newzealand': 716,
#  'offbeat': 717,
#  'truetf2': 718,
#  'battlefield_4': 719,
#  'css': 720,
#  'mtgfinance': 721,
#  'kpop': 722,
#  'SquaredCircle': 723,
#  'waiting_to_try': 724,
#  'touhou': 725,
#  'cowboys': 726,
#  'sweden': 727,
#  'perfectloops': 728,
#  'RealEstate': 729,
#  'nutrition': 730,
#  'DenverBroncos': 731,
#  'Firearms': 732,
#  'EarthPorn': 733,
#  'ProgrammerHumor': 734,
#  'litecoin': 735,
#  'Autos': 736,
#  'chromeos': 737,
#  'declutter': 738,
#  'comics': 739,
#  'ireland': 740,
#  'cider': 741,
#  'hearthstone': 742,
#  'fireemblem': 743,
#  'SVExchange': 744,
#  'poker': 745,
#  'AskMenOver30': 746,
#  'spikes': 747,
#  'quityourbullshit': 748,
#  'bodyweightfitness': 749,
#  'chemistry': 750,
#  'creepyPMs': 751,
#  'nerdcubed': 752,
#  'PixelDungeon': 753,
#  'transgender': 754,
#  'vexillology': 755,
#  'projectzomboid': 756,
#  'leafs': 757,
#  'letsplay': 758,
#  'DJs': 759,
#  'providence': 760,
#  'Chefit': 761,
#  'askgaybros': 762,
#  'Calgary': 763,
#  'pystats': 764,
#  'TruePokemon': 765,
#  'GTA': 766,
#  'jailbreak': 767,
#  'EDH': 768,
#  'NorthKoreaNews': 769,
#  'UKPersonalFinance': 770,
#  'elderscrollsonline': 771,
#  'Pathfinder': 772,
#  'paintball': 773,
#  'Fallout': 774,
#  'fnv': 775,
#  'dogecoin': 776,
#  'SkincareAddiction': 777,
#  'asmr': 778,
#  'teslore': 779,
#  'LunaLounge': 780,
#  'bleach': 781,
#  'Coffee': 782,
#  'PostCollapse': 783,
#  'latterdaysaints': 784,
#  'CCW': 785,
#  'paydaytheheist': 786,
#  'FIFA': 787,
#  'TrueChristian': 788,
#  'ArtisanVideos': 789,
#  'NorthCarolina': 790,
#  'italy': 791,
#  'furry': 792,
#  'Debate': 793,
#  'ladybonersgw': 794,
#  'Hiphopcirclejerk': 795,
#  'billiards': 796,
#  'BSG': 797,
#  'AmericanHorrorStory': 798,
#  'RotMG': 799,
#  'civ': 800,
#  'buildapcforme': 801,
#  'finance': 802,
#  'purebattlefield': 803,
#  'flightsim': 804,
#  'toronto': 805,
#  'javascript': 806,
#  'bonnaroo': 807,
#  'makemychoice': 808,
#  'Beekeeping': 809,
#  'TheBluePill': 810,
#  '3d6': 811,
#  'mcpublic': 812,
#  'ConnectedCareers': 813,
#  'debian': 814,
#  'Cubs': 815,
#  'arma3': 816,
#  'daddit': 817,
#  'realmadrid': 818,
#  'trainerroad': 819,
#  'subaru': 820,
#  'BuyItForLife': 821,
#  'CODGhosts': 822,
#  'indieheads': 823,
#  'civ5': 824,
#  'discgolf': 825,
#  'SampleSize': 826,
#  'ffxi': 827,
#  'dragonage': 828,
#  'TrueDetective': 829,
#  'bmx': 830,
#  'forwardsfromgrandma': 831,
#  'SRSAnime': 832,
#  'UCSD': 833,
#  'SubrichardDawkins': 834,
#  'chelseafc': 835,
#  'fatlogic': 836,
#  'gamingsuggestions': 837,
#  'CombatFootage': 838,
#  'ftm': 839,
#  'gainit': 840,
#  'Briggs': 841,
#  'carporn': 842,
#  'kansascity': 843,
#  'acting': 844,
#  'evolutionReddit': 845,
#  'FanFicCrits': 846,
#  'aviation': 847,
#  'collegehockey': 848,
#  'Monstercat': 849,
#  'MTB': 850,
#  'NZXT': 851,
#  'Jeep': 852,
#  'SanJoseSharks': 853,
#  'japan': 854,
#  'vapeitforward': 855,
#  'opieandanthony': 856,
#  'Pokemonbreeding': 857,
#  'MapPorn': 858,
#  'UCONN': 859,
#  'Braveryjerk': 860,
#  'cocaine': 861,
#  'weddingplanning': 862,
#  'ft86': 863,
#  'mflb': 864,
#  'theydidthemath': 865,
#  'premed': 866,
#  'teaching': 867,
#  'IWantOut': 868,
#  'ultimate': 869,
#  'web_design': 870,
#  'itookapicture': 871,
#  'Citibike': 872,
#  'freemasonry': 873,
#  'SRSWomen': 874,
#  'lgbt': 875,
#  'KitchenConfidential': 876,
#  'TransSupport': 877,
#  'Hawaii': 878,
#  'howto': 879,
#  'ultrahardcore': 880,
#  'infamous': 881,
#  'piano': 882,
#  'BipolarReddit': 883,
#  'education': 884,
#  'Ubuntu': 885,
#  'ipad': 886,
#  'hacking': 887,
#  'Pottery': 888,
#  'PenmanshipPorn': 889,
#  'gadgets': 890,
#  'chess': 891,
#  'rupaulsdragrace': 892,
#  'socialanxiety': 893,
#  'DarkSouls2': 894,
#  'altpug': 895,
#  'OneY': 896,
#  'gaysian': 897,
#  'britishproblems': 898,
#  'breastfeeding': 899,
#  'bestofbronze': 900,
#  'stopdrinking': 901,
#  'hockeygoalies': 902,
#  'Barca': 903,
#  'OpenPV': 904,
#  'rit': 905,
#  'Lollapalooza': 906,
#  'Scotland': 907,
#  'HomeworkHelp': 908,
#  'Autoflowers': 909,
#  'Chinavisa': 910,
#  'AppalachianTrail': 911,
#  'GhostReconPhantoms': 912,
#  'singularity': 913,
#  'userexperience': 914,
#  'livesound': 915,
#  'FIU': 916,
#  'fresno': 917,
#  'twitchplayspokemon': 918,
#  'Yogscast': 919,
#  'wargame': 920,
#  'leaves': 921,
#  'Roku': 922,
#  'ChineseLanguage': 923,
#  'reddevils': 924,
#  'DungeonsAndDragons': 925,
#  'Reformed': 926,
#  'TampaBayLightning': 927,
#  'Winnipeg': 928,
#  'youtube': 929,
#  'Dexter': 930,
#  'mentalhealth': 931,
#  'MakeupAddicts': 932,
#  'triathlon': 933,
#  'AMA': 934,
#  'Poetry': 935,
#  'CrappyDesign': 936,
#  'Scams': 937,
#  'androidapps': 938,
#  'Bravenewbies': 939,
#  'DarkNetMarkets': 940,
#  'medicine': 941,
#  'RedditForGrownups': 942,
#  'SMITEGODCONCEPTS': 943,
#  'Nationals': 944,
#  'Montford': 945,
#  'aquaponics': 946,
#  'Awesomenauts': 947,
#  'pokemonzetaomicron': 948,
#  'h1z1': 949,
#  'short': 950,
#  'uOttawaEcon': 951,
#  'worldpowers': 952,
#  'NewYorkMets': 953,
#  'gtaonline': 954,
#  'UnresolvedMysteries': 955,
#  'StackAdvice': 956,
#  'qotsa': 957,
#  'CannabisExtracts': 958,
#  'sto': 959,
#  'JohnMayer': 960,
#  'NewOrleans': 961,
#  'books': 962,
#  'LetsTalkMusic': 963,
#  'Reds': 964,
#  'DesertRock': 965,
#  'Borderlands2': 966,
#  '2007scape': 967,
#  'BitcoinMarkets': 968,
#  '24hoursupport': 969,
#  'educationalgifs': 970,
#  'riddles': 971,
#  'Tulpas': 972,
#  'arma': 973,
#  'PixelArt': 974,
#  'literature': 975,
#  'ABraThatFits': 976,
#  'csgobetting': 977,
#  'OutreachHPG': 978,
#  'Diablo3DemonHunters': 979,
#  'amiwrong': 980,
#  'FocusT25': 981,
#  'collegebaseball': 982,
#  'infp': 983,
#  'orangeisthenewblack': 984,
#  'ModernMagic': 985,
#  'spaceengineers': 986,
#  'German': 987,
#  'Cricket': 988,
#  'evenewbies': 989,
#  'wedding': 990,
#  'entp': 991,
#  'TheGirlSurvivalGuide': 992,
#  'bestofTLDR': 993,
#  'Tacoma': 994,
#  'Battlefield': 995,
#  'northernireland': 996,
#  'vim': 997,
#  'bioniclelego': 998,
#  'Cumberbitches': 999,
#  'recht': 1000,
#  ...}

# %%
idx = max(data['user_id']) + 1

# %%
tdf['user_id'] = idx

# %%
tdf
# Out:
#     index           subreddit  rating  reddit_id
# 0       0                math     101          1
# 1       1            Frontend     101       3898
# 2       2            ethereum     101       3276
# 3       3     MachineLearning     104       2944
# 4       4          artificial     101       2279
# 5       8           2007scape     104        967
# 6      10               umass     103       1533
# 7      12          conspiracy     101        255
# 8      13                ADHD     104        313
# 9      14             reactjs     102      12883
# 10     15      wallstreetbets     103       2238
# 11     16              golang     101       7766
# 12     17            politics     101         74
# 13     18         datascience     101       2085
# 14     20   cscareerquestions     111        616
# 15     22   ApplyingToCollege     101      11832
# 16     24      iOSProgramming     101       4636
# 17     26  ProgrammingBuddies     101      24319
# 18     27              docker     101      15490

# %%
df_train = data.append(tdf, ignore_index=True)

# %%
df_train
# Out:
#          user_id  reddit_id  rating  index           subreddit
# 0              1          1       1    NaN                 NaN
# 1              1         66       1    NaN                 NaN
# 2              1        134       1    NaN                 NaN
# 3              1          2       1    NaN                 NaN
# 4              1         10       1    NaN                 NaN
# ...          ...        ...     ...    ...                 ...
# 2536268  1462080        616     111   20.0   cscareerquestions
# 2536269  1462080      11832     101   22.0   ApplyingToCollege
# 2536270  1462080       4636     101   24.0      iOSProgramming
# 2536271  1462080      24319     101   26.0  ProgrammingBuddies
# 2536272  1462080      15490     101   27.0              docker
#
# [2536273 rows x 5 columns]

# %%
df_test = pd.DataFrame(np.array( [i for i in s2I.values()]), columns=["reddit_id"])
df_test['user_id'] = idx

# %%
df_test
# Out:
#        reddit_id  user_id
# 0              1  1462080
# 1              2  1462080
# 2              3  1462080
# 3              4  1462080
# 4              5  1462080
# ...          ...      ...
# 29646      29647  1462080
# 29647      29648  1462080
# 29648      29649  1462080
# 29649      29650  1462080
# 29650      29651  1462080
#
# [29651 rows x 2 columns]

# %%
explanation_columns = ['user_id', 'reddit_id']

# %%
ohe = OneHotEncoder(handle_unknown='ignore')
X_train = ohe.fit_transform(df_train[explanation_columns])
X_test = ohe.transform(df_test[explanation_columns])
y_train = df_train.rating.values

# %%
fm = myfm.MyFMRegressor(rank=8, random_seed=334)

# %%
X_train *= 1
X_test *= 1

# %%
fm.fit(X_train, y_train, grouping=None, n_iter=200, n_kept_samples=195)
# Out:
# alpha = 0.00 w0 = 1.53 :  72%|▋

# %%
prediction = fm.predict(X_test)
print(prediction)

# %%
prediction_to_subreddit = {k+1:v for k,v in enumerate(prediction)}

# %%
prediction_keys = sorted(prediction_to_subreddit, key=prediction_to_subreddit.get)

# %%
best = prediction_keys[-30:]
worst = prediction_keys[:30]

# %%
I2s = {v:k for k, v in s2I.items()}

# %%
print([I2s[b] for b in best])
# Out:
# ['San_Angelo', 'sweetfx', 'pwettypwinkpwincesses', 'ConspiracyMemes', 'theDS', 'theholdsteady', 'MyastheniaGravis', 'CSGOCastIt', 'MCNSA', 'wargame', 'gambling', 'euguild', 'fairphone', 'Scootering', 'AskEthics', 'dbzu', 'MyLittleMotorhead', 'trpfanfiction', 'BronyH8', 'RUGC_India', 'YouTubeGamers', 'PracticeModerating', 'FixedGearBikes', 'MeatDepartment', 'lasercutting', 'digg', 'GameTrade', 'leagueoflegends', 'relationships', 'AskReddit']

# %%
print([I2s[w] for w in worst])
# Out:
# ['otherkin', 'payitforward', 'drunkenpeasants', 'ausents', 'dcpu16', 'Nbome', 'Shinecraft', 'shardsonline', 'CODAliens', 'sportsmedicine', 'thegleeproject', 'genderfuck', 'MayhemSanctum', '1984', 'clevelandcavs', 'chicagojobs', 'scorpion', 'crossdressing', 'truegaming', 'UnionHouse', 'aesthetics', 'needadvice', 'Anger', 'religiondebate', 'wowgaymers', 'visas', 'HecarimMains', 'fuckmyboss', 'FutureFight_Unions', 'Dreadfort']

# %%
prediction = fm.predict(tdf)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3f/md0t9sgj6rz8xy01fskttqdc0000gn/T/ipykernel_5623/2818256089.py in <module>
# ----> 1 prediction = fm.predict(X_test)
#
# /usr/local/anaconda3/envs/og-env/lib/python3.9/site-packages/myfm/gibbs.py in predict(self, X, X_rel, n_workers)
#     213             One-dimensional array of predictions.
#     214         """
# --> 215         return self._predict(X, X_rel, n_workers=n_workers)
#     216
#     217
#
# /usr/local/anaconda3/envs/og-env/lib/python3.9/site-packages/myfm/base.py in _predict(self, X, X_rel, n_workers)
#     361         n_workers: Optional[int] = None,
#     362     ) -> np.ndarray:
# --> 363         return self._predict_core(X, X_rel, n_workers=n_workers)
#     364
#     365
#
# /usr/local/anaconda3/envs/og-env/lib/python3.9/site-packages/myfm/gibbs.py in _predict_core(self, X, X_rel, n_workers)
#      54             X = sps.csr_matrix(X)
#      55         if n_workers is None:
# ---> 56             return predictor.predict(X, X_rel)
#      57         else:
#      58             return predictor.predict_parallel(X, X_rel, n_workers)
#
# KeyboardInterrupt:

# %%
tdf
# Out:
#              subreddit  ranking  reddit_id
# 0            2007scape        4        967
# 1                umass        3       1533
# 2           conspiracy        1        255
# 3                 ADHD        4        313
# 4              reactjs        2      12883
# 5      MachineLearning        3       2944
# 6       wallstreetbets        3       2238
# 7               golang        1       7766
# 8             politics        1         74
# 9          datascience        1       2085
# 10   cscareerquestions       11        616
# 11   ApplyingToCollege        1      11832
# 12      iOSProgramming        1       4636
# 13  ProgrammingBuddies        1      24319
# 14              docker        1      15490
