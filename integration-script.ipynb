# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/My Drive/UMass")

# %%
from getpass import getpass

# %%
TOKEN=getpass("Enter github token: ")
USER="smeyerhot"
PROJECT="CS685"
# Out:
# Enter github token: ··········

# %%
GIT_PATH = "https://" + TOKEN + "@github.com/" + USER + "/" + PROJECT + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# GIT_PATH:  https://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@github.com/smeyerhot/CS685.git

# %%
# !git clone "{GIT_PATH}"
# Out:
# fatal: remote origin already exists.

# %%
cd CS685/
# Out:
# [Errno 2] No such file or directory: 'CS685/'
# /content/drive/My Drive/UMass/CS685

# %%
# !git checkout main
# Out:
# Switched to branch 'main'
# Your branch is up to date with 'origin/main'.

# %%
# !git pull "{GIT_PATH}"
# Out:
# From https://github.com/smeyerhot/CS685
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !git rebase origin/main
# Out:
# Current branch add-github-integration is up to date.

# %%
# !git checkout -b training-loop-dev
# Out:
# Switched to a new branch 'training-loop-dev'

# %%
# When its time to commit and push

# %%
# !git add --all

# %%
# !git config --global user.email "smeyerhot@gmail.com"

# %%
# !git config --global user.email "tsm"

# %%
# !git commit -m "Add Covid Data"
# Out:
# [add-github-integration cf4f107] Add Covid Data
#  2 files changed, 7560 insertions(+), 1 deletion(-)
#  create mode 100644 COVID-Dialogue-Dataset-English.txt

# %%
# !git push "{GIT_PATH}" origin add-github-integration
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 139.05 KiB | 3.86 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/smeyerhot/CS685.git
#    9dcef07..cf4f107  add-github-integration -> add-github-integration
