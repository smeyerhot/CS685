# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/My Drive/UMass")

# %%
TOKEN=input("enter token >>")
USER=input("enter username >>")
PROJECT=input("enter project >>")
# Out:
# enter token >>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
# enter username >>smeyerhot
# enter username >>CS685

# %%
GIT_PATH = "https://" + TOKEN + "@github.com/" + USER + "/" + PROJECT + ".git"
print("GIT_PATH: ", GIT_PATH)
# Out:
# GIT_PATH:  https://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@github.com/smeyerhot/CS685.git

# %%
# !git clone "{GIT_PATH}"
# Out:
# fatal: remote origin already exists.

# %%
cd CS685/
# Out:
# /content/drive/My Drive/UMass/CS685

# %%
# !git checkout add-github-integration
# Out:
# Already on 'add-github-integration'

# %%
# !git pull "{GIT_PATH}"
# Out:
# From https://github.com/smeyerhot/CS685
#  * branch            HEAD       -> FETCH_HEAD
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Not committing merge; use 'git commit' to complete the merge.

# %%
# !git rebase origin/main
# Out:
# Current branch add-github-integration is up to date.

# %%
# !git add --all

# %%
# !git config --global user.email "smeyerhot@gmail.com"

# %%
# !git config --global user.email "tsm"

# %%
# !git commit -m "Add code but not large files"
# Out:
# [add-github-integration e205669] Add code but not large files
#  4 files changed, 1881 insertions(+), 2536 deletions(-)
#  rename separate_doctor_patient.ipynb => decoder_only.ipynb (53%)

# %%
# !git push "{GIT_PATH}" origin add-github-integration
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 38.42 KiB | 3.49 MiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# remote:
# remote: Create a pull request for 'add-github-integration' on GitHub by visiting:
# remote:      https://github.com/smeyerhot/CS685/pull/new/add-github-integration
# remote:
# To https://github.com/smeyerhot/CS685.git
#  * [new branch]      add-github-integration -> add-github-integration

# %%
# !echo ".DS_Store" >> .gitignore

# %%
# !ls
# Out:
# data.py		    helper.py			      plots.py
# decoder_only.ipynb  integration-script.ipynb	      __pycache__
# gpt_covid.ipynb     Medical-Dialogue-Dataset-English  README.md

# %%
# !cat .gitignore
# Out:
# Medical-Dialogue-Dataset-English/
# Medical-Dialogue-Dataset-English/
# .DS_Store
