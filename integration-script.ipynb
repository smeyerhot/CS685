# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/My Drive/UMass")

# %%
from getpass import getpass

# %%
TOKEN=getpass("Enter github token: ")
USER="smeyerhot"
PROJECT="CS685"
# Out:
# Enter github token: ··········

# %%
GIT_PATH = "https://" + TOKEN + "@github.com/" + USER + "/" + PROJECT + ".git"

# %%
# !git clone "{GIT_PATH}"
# Out:
# fatal: remote origin already exists.

# %%
cd CS685/
# Out:
# [Errno 2] No such file or directory: 'CS685/'
# /content/drive/My Drive/UMass/CS685

# %%
# !git checkout main
# Out:
# Switched to branch 'main'
# Your branch is ahead of 'origin/main' by 8 commits.
#   (use "git push" to publish your local commits)

# %%
# !git pull "{GIT_PATH}"
# Out:
# From https://github.com/smeyerhot/CS685
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !git checkout -b loop-dev
# Out:
# Switched to a new branch 'loop-dev'

# %%
# When its time to commit and push

# %%
# !git add --all

# %%
# !git config --global user.email "smeyerhot@gmail.com"

# %%
# !git config --global user.email "tsm"

# %%
# !git commit -m "addition by subtraction"
# Out:
# On branch loop-dev
# nothing to commit, working tree clean

# %%
# !git push "{GIT_PATH}" origin loop-dev
# Out:
# Total 0 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'loop-dev' on GitHub by visiting:
# remote:      https://github.com/smeyerhot/CS685/pull/new/loop-dev
# remote:
# To https://github.com/smeyerhot/CS685.git
#  * [new branch]      loop-dev -> loop-dev

# %%
# !git branch -D training-loop-dev
# Out:
# Deleted branch training-loop-dev (was dcd2ea7).
