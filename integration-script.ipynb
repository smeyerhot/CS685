# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import os
os.chdir("/content/drive/My Drive/UMass")

# %%
from getpass import getpass

# %%
TOKEN=getpass("Enter github token: ")
USER="smeyerhot"
PROJECT="CS685"
# Out:
# Enter github token: ··········

# %%
GIT_PATH = "https://" + TOKEN + "@github.com/" + USER + "/" + PROJECT + ".git"

# %%
# !git clone "{GIT_PATH}"
# Out:
# fatal: remote origin already exists.

# %%
cd CS685/
# Out:
# [Errno 2] No such file or directory: 'CS685/'
# /content/drive/My Drive/UMass/CS685

# %%
# !git checkout main
# Out:
# Switched to branch 'main'
# Your branch is up to date with 'origin/main'.

# %%
# !git pull "{GIT_PATH}"
# Out:
# From https://github.com/smeyerhot/CS685
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !git rebase origin/main
# Out:
# Current branch add-github-integration is up to date.

# %%
# !git checkout -b training-loop-dev
# Out:
# Switched to a new branch 'training-loop-dev'

# %%
# When its time to commit and push

# %%
# !git add --all

# %%
# !git config --global user.email "smeyerhot@gmail.com"

# %%
# !git config --global user.email "tsm"

# %%
# !git commit -m "get pass for token"
# Out:
# [training-loop-dev e386dea] get pass for token
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite integration-script.ipynb (90%)

# %%
# !git push "{GIT_PATH}" origin training-loop-dev
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.45 KiB | 372.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# remote:
# remote: Create a pull request for 'training-loop-dev' on GitHub by visiting:
# remote:      https://github.com/smeyerhot/CS685/pull/new/training-loop-dev
# remote:
# To https://github.com/smeyerhot/CS685.git
#  * [new branch]      training-loop-dev -> training-loop-dev
